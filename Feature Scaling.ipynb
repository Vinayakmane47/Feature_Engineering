# %% [markdown]
# ### 1. Standardizing the features (Z-Score) :
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 2. Performing mean normalization :
# ![image.png](attachment:image.png)
# - Convert values b/w -1 to 1

# %%
mean = mean 
ranges = max - min 
X_train_scaled = (X_train - mean) / ranges

# %% [markdown]
# ### 3. Scaling to the maximum and minimum values
# ![image.png](attachment:image.png)
# - Convert Values into 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler
mean = mean 
ranges = max - min 
X_train_scaled = (X_train - min) / ranges

## By using sckit-learn : 
scalar = MinMaxScaler()
scalar.fit_transform(x_train)

# %% [markdown]
# ### 4. Implementing maximum absolute scaling
# ![image.png](attachment:image.png)
#
# - Convert values into -1 to 1

# %%
from sklearn.preprocessing import MaxAbsScaler
scalar = MaxAbsScaler()
scalar.fit_transform(x_train)

# %% [markdown]
# ### 5. Scaling with the median and quantiles(Robust Scaling)
# ![image.png](attachment:image.png)
#
# - It is used  if the data contains outliers

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit_transform(X_train)

# %% [markdown]
# ### 6. Scaling to vector unit length
# - Scaling to the unit norm is achieved by dividing each observation vector by either the Manhattan distance (l1 norm) or the Euclidean distance (l2 norm) of the vector. The Manhattan distance is given by the sum of the absolute components of the vector:
# - Manhatten Distance l1
# ![image.png](attachment:image.png)
#
# - Eucledian Distance l2
# ![image-2.png](attachment:image-2.png)

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer(norm='l1') --> for manhatten distance
scaler = Normalizer(norm='l2') --> for eucledian distance

scaler.fit_transform(X_train)
