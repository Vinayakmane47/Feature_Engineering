# %% [markdown]
# ### 1. Combining multiple features with statistical operations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Combining pairs of features with mathematical functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Performing polynomial expansion

# %% [markdown]
# - second degree polynomial features - it creates feature like this
# ![image.png](attachment:image.png)
#
# - third degree polynomial features
# ![image-2.png](attachment:image-2.png)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, interaction_only=False,include_bias=False)
## include_bias = False it neglectes bias value i.e. 1 
poly.fit(X_train[['LSTAT', 'RM', 'NOX']])
train_t = poly.transform(X_train[['LSTAT', 'RM', 'NOX']])
test_t = poly.transform(X_test[['LSTAT', 'RM', 'NOX']])
## Converting to dataframe 
test_t = pd.DataFrame(test_t)
test_t.columns = poly.get_feature_names(['LSTAT', 'RM', 'NOX'])

# %% [markdown]
# ### 4.Deriving new features with decision trees
# - Creating new feature using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': [3, 4, None]}
tree_model = GridSearchCV(DecisionTreeRegressor(random_state=0),
                                             cv = 5,
                                             scoring = 'neg_mean_squared_error',
                                             param_grid = param_grid)

tree_model.fit(X_train[['LSTAT', 'RM', 'NOX']], y_train)

## Deriving the new feature new_feat using 3 features 
X_train['new_feat'] = tree_model.predict(X_train[['LSTAT', 'RM','NOX']])
X_test['new_feat'] = tree_model.predict(X_test[['LSTAT', 'RM','NOX']])

# %% [markdown]
# ### 5. Carrying out PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=None)
pca.fit_transform(x_train)

plt.plot(pca.explained_variance_ratio_)
plt.title('Percentage of Variance Explained')
plt.xlabel('Number of Components')
plt.ylabel('Percentage of Variance Explained')

# %%
list1 = [1,2,3,4,5,5] 
print(id(list1))
# Out:
# 2419517877248

# %%
list1 = ['a','v','d','b'] 
print(id(list1))
# Out:
# 2419518595776
